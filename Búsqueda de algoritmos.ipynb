# %%
import pandas as pd

# Cargar una hoja específica
df_excel = pd.read_excel("Resumen algoritmos.xlsx", sheet_name="Regresion")

# Ver las primeras filas
df_excel.head()
# Out:
#    ID                                       Algoritmo Tipo de aprendizaje  \
# 0   1                         Regresión lineal simple         Supervisado
# 1   3                            Regresión polinómica         Supervisado
# 2   4  Regresión con máquina de soporte vectorial SVR         Supervisado
# 3   5               Regresión con árboles de decisión         Supervisado
# 4   6                Regresión con bosques aleatorios         Supervisado
#
#   Tipo de dato que recibe Tipo de dato que arroja  \
# 0                Continuo                Continuo
# 1                Continuo                Continuo
# 2                Continuo                Continuo
# 3                Continuo                Continuo
# 4                Continuo                Continuo
#
#                                           Ventajas  \
# 0                                Sencillo y rápido
# 1                   Captura relaciones no lineales
# 2                 Maneja bien alta dimensionalidad
# ...
